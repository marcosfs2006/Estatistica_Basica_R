# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1h_07KvMIw8cHB5DWLdnZMFRoXfDuHS9W" width="500" height="100">

# %% [markdown]
# # **Estatística Básica com R**
#
# Instrutor: **Marcos Ferreira da Silva**
#
# <br>
#
# Programa do Curso:
#
# Dias **25 e 30/08/2002**
#
# * Apresentação do R/RStudio
# * Classificação das variáveis
# * Distribuição de Frequencias
# * Medidas descritivas
# * Análise Exploratória de Dados
#
# Dias **01 e 06/09/2022**
#
# * Introdução à estimação
# * Testes de hipóteses
# * Intervalores de confiança
#
# Dias **08 e 13/09/2022**
#
# * Análise de correlações
# * Modelo de regressão linear simples e múltipla

# %% [markdown]
# 💢 Notebooks e dados estão disponíveis no repositório do curso no GitHub:
#
# $\qquad$<https://github.com/marcosfs2006/Estatistica_Basica_R>
#
# <br>
#
# **Material Complementar**
#
# * [Sobre Visualização de Dados e Auditoria](https://www.rpubs.com/marcosfs2006/dataviz)
# * [Análise de Dados Aplicada à Auditoria com R](https://colab.research.google.com/drive/1nHhHNGRheKaehgQetEh_fPU99CQLwmSt?usp=sharing)
# * [Blog - Audinalytics: Auditoria com Inteligência Analítica](https://audinalytics.netlify.app/blog.html)
